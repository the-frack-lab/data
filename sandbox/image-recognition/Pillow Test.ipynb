# %%
from PIL import Image

# %%
im = Image.open("snapshot.tif")

# %%
im.format
# Out:
# 'TIFF'

# %%
im.size
# Out:
# (1032, 161)

# %%
im.mode
# Out:
# 'RGB'

# %%
im.show()

# %%
data = im.getdata()

# %%
list(data)
# Out:
# [(0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
#  (0, 38, 115),
# ...

# %%
len(list(data))
# Out:
# 166152
