# %%
from __future__ import division
from collections import defaultdict, OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import pylab
from scipy import ndimage
from PIL import Image
from ipythonblocks import show_color, ImageGrid

# %%
file = "Tarrant-cleaned.png"
tarrant = Image.open(file)

# %%
def get_color_values_for_row(rowindex, row):
    color_values = []
    true_count = 0
    for colindex, sobvalue in enumerate(row):
            # sum the array and see if it's 0 
            color_total = sobvalue.sum()
            if color_total == 0:
                true_count = true_count + 1
            else:
                if true_count != 0 and true_count > 11:
                    square_color = tarrant_pil.getpixel((colindex, rowindex))
                    color_values.append(square_color)
                    true_count = 0   
    return color_values

def get_candidate_indexes(sobarray):
    array_indexes = []
    true_count = 0
    for colindex, sobvalue in enumerate(sobarray):
            # sum the array and see if it's 0
            color_total = sobvalue.sum()
            if color_total == 0:
                true_count = true_count + 1
            else:
                if true_count != 0 and true_count > 10:
                    array_indexes.append(colindex - 10)
                    true_count = 0
    return array_indexes

# %%
# Thanks to http://scipy-lectures.github.io/advanced/image_processing/#edge-detection
sx = ndimage.sobel(tarrant, axis=0, mode='constant')
sy = ndimage.sobel(tarrant, axis=1, mode='constant')
sob = np.hypot(sx, sy)
#pylab.imshow(sob)

# %%
sob_t = sob.transpose(1,0,2)
#pylab.imshow(sob_t)

# %% [markdown]
# # Get candidate row and columns (takes time)

# %%
candidate_rows = []
for row in sob_t:
    candidate_rows.append(get_candidate_indexes(row))

# %%
candidate_columns = []
for column in sob:
    candidate_columns.append(get_candidate_indexes(column))

# %% [markdown]
# # Clean up rows and columns

# %%
# Source: https://stackoverflow.com/questions/19878250/zero-padding-numpy-array
# Build a zero padded array from uneven length lists
def apply_to_zeros(lst, dtype=np.int64):
    inner_max_len = max(map(len, lst))
    result = np.zeros([len(lst), inner_max_len], dtype)
    for i, row in enumerate(lst):
        for j, val in enumerate(row):
            result[i][j] = val
    return result

candidate_rows_array = apply_to_zeros(candidate_rows)
candidate_columns_array = apply_to_zeros(candidate_columns)

number_of_rows = candidate_rows_array.shape[1]
number_of_columns = candidate_columns_array.shape[1]

print number_of_rows
print number_of_columns
# Out:
# 29
# 38

# %%
def get_points(number, array):
    items = []
    for i in xrange(number):
        item = np.median(array[i])
        if item != 0:
            items.append(int(item))
    return items

# %%
rows = get_points(number_of_rows, candidate_rows_array.transpose(1,0))
columns = get_points(number_of_columns, candidate_columns_array.transpose(1,0))
print rows
print columns
# Out:
# [46, 101, 155, 210, 267, 322, 376, 431, 486, 540, 597, 652, 707, 761, 816, 873, 928, 982, 1037, 1091, 1146, 1203, 1258, 1312, 1367, 1422, 1479]
# [42, 96, 151, 208, 263, 317, 372, 427, 481, 538, 593, 648, 702, 757, 814, 869, 923, 978, 1032, 1087, 1144, 1199, 1253, 1308, 1363, 1420, 1474, 1529, 1584, 1638, 1693, 1750]

# %% [markdown]
# # Put it all together

# %%
# Go and get the colors from the image
color_array = []
for rowindex in rows:
    row_array = []
    for colindex in columns:
        row_array.append(tarrant.getpixel((colindex, rowindex)))
    color_array.append(row_array)

# %%
np_color_array = np.array(color_array)
shape = np_color_array.shape
print shape
# Out:
# (27, 32, 3)

# %%
grid = ImageGrid(shape[1], shape[0], block_size=8)
offset = grid.height - 1
for r in range(grid.height):
    for c in range(grid.width):
        pixel = grid[c, offset - r]
        pixel.red = color_array[r][c][0]
        pixel.green = color_array[r][c][1]
        pixel.blue = color_array[r][c][2]
grid.show()
pylab.imshow(tarrant)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf13c2d09-5133-4511-8753-5f35e6654527 td {border: 1px solid white;}</style><table id="blocksf13c2d09-5133-4511-8753-5f35e6654527" class="blockgrid"><tbody><tr><td title="Index: [0, 26]&#10;Color: (248, 185, 136)" style="width: 8px; height: 8px;background-color: rgb(248, 185, 136);"></td><td title="Index: [1, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [2, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [3, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [4, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [5, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [6, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [7, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [8, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [9, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [10, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [11, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [12, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [13, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [14, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [15, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [16, 26]&#10;Color: (228, 97, 72)" style="width: 8px; height: 8px;background-color: rgb(228, 97, 72);"></td><td title="Index: [17, 26]&#10;Color: (71, 118, 179)" style="width: 8px; height: 8px;background-color: rgb(71, 118, 179);"></td><td title="Index: [18, 26]&#10;Color: (233, 236, 192)" style="width: 8px; height: 8px;background-color: rgb(233, 236, 192);"></td><td title="Index: [19, 26]&#10;Color: (233, 236, 192)" style="width: 8px; height: 8px;background-color: rgb(233, 236, 192);"></td><td title="Index: [20, 26]&#10;Color: (212, 49, 46)" style="width: 8px; height: 8px;background-color: rgb(212, 49, 46);"></td><td title="Index: [21, 26]&#10;Color: (254, 232, 176)" style="width: 8px; height: 8px;background-color: rgb(254, 232, 176);"></td><td title="Index: [22, 26]&#10;Color: (154, 174, 188)" style="width: 8px; height: 8px;background-color: rgb(154, 174, 188);"></td><td title="Index: [23, 26]&#10;Color: (192, 204, 190)" style="width: 8px; height: 8px;background-color: rgb(192, 204, 190);"></td><td title="Index: [24, 26]&#10;Color: (233, 236, 192)" style="width: 8px; height: 8px;background-color: rgb(233, 236, 192);"></td><td title="Index: [25, 26]&#10;Color: (254, 232, 176)" style="width: 8px; height: 8px;background-color: rgb(254, 232, 176);"></td><td title="Index: [26, 26]&#10;Color: (248, 185, 136)" style="width: 8px; height: 8px;background-color: rgb(248, 185, 136);"></td><td title="Index: [27, 26]&#10;Color: (240, 141, 102)" style="width: 8px; height: 8px;background-color: rgb(240, 141, 102);"></td><td title="Index: [28, 26]&#10;Color: (240, 141, 102)" style="width: 8px; height: 8px;background-color: rgb(240, 141, 102);"></td><td title="Index: [29, 26]&#10 ...

# %% [markdown]
# # Convert into values

# %%
color_list = []
for row in color_array:
    color_list.extend(row)

# %%
# Build a histogram
d = defaultdict(int)
for x in color_list: 
    d[x] += 1

#Need % rgb values not 255 values for matplotlib
d_normalized = defaultdict(int)
for key in d.keys():
    new_key = tuple(rgb/255 for rgb in key)
    d_normalized[new_key] = d[key]
# Out:
# defaultdict(<type 'int'>, {(0.7529411764705882, 0.8, 0.7450980392156863): 53, (0.43529411764705883, 0.5647058823529412, 0.7137254901960784): 25, (0.2784313725490196, 0.4627450980392157, 0.7019607843137254): 30, (0.996078431372549, 0.9098039215686274, 0.6901960784313725): 93, (0.8313725490196079, 0.19215686274509805, 0.1803921568627451): 207, (0.9725490196078431, 0.7254901960784313, 0.5333333333333333): 114, (0.6039215686274509, 0.6823529411764706, 0.7372549019607844): 49, (0.0, 0.0, 0.0): 2, (0.9411764705882353, 0.5529411764705883, 0.4): 128, (0.9137254901960784, 0.9254901960784314, 0.7529411764705882): 68, (0.8941176470588236, 0.3803921568627451, 0.2823529411764706): 95})

# %%
x = np.arange(len(d_normalized))
plt.bar(x, d_normalized.values(), color=d_normalized.keys())
plt.xticks(x+0.5, d_normalized.keys(), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f2b524920d0>,
#   <matplotlib.axis.XTick at 0x7f2b5a56c710>,
#   <matplotlib.axis.XTick at 0x7f2b558707d0>,
#   <matplotlib.axis.XTick at 0x7f2b522c9810>,
#   <matplotlib.axis.XTick at 0x7f2b522c9f50>,
#   <matplotlib.axis.XTick at 0x7f2b522f46d0>,
#   <matplotlib.axis.XTick at 0x7f2b522f4e10>,
#   <matplotlib.axis.XTick at 0x7f2b522fe590>,
#   <matplotlib.axis.XTick at 0x7f2b522fecd0>,
#   <matplotlib.axis.XTick at 0x7f2b524f1450>,
#   <matplotlib.axis.XTick at 0x7f2b524f1b90>],
#  <a list of 11 Text xticklabel objects>)

# %%
lookup = OrderedDict([
    ((0, 0, 0), "error"),
    ((0.2784313725490196, 0.4627450980392157, 0.7019607843137254), "< 0.5"),
    ((0.43529411764705883, 0.5647058823529412, 0.7137254901960784), "0.5"),
    ((0.6039215686274509, 0.6823529411764706, 0.7372549019607844), "0.9"),
    ((0.7529411764705882, 0.8, 0.7450980392156863), "1.2"),
    ((0.9137254901960784, 0.9254901960784314, 0.7529411764705882), "1.5"),
    ((0.996078431372549, 0.9098039215686274, 0.6901960784313725), "1.9"),
    ((0.9725490196078431, 0.7254901960784313, 0.5333333333333333), "2.3"),
    ((0.9411764705882353, 0.5529411764705883, 0.4), "2.8"),
    ((0.8941176470588236, 0.3803921568627451, 0.2823529411764706), "3.4"),
    ((0.8313725490196079, 0.19215686274509805, 0.1803921568627451), "> 4.3"),
])
lookup_denormalized = OrderedDict()
for key in lookup.keys():
    new_key = tuple(rgb*255 for rgb in key)
    lookup_denormalized[new_key] = lookup[key]

# %%
d_values = OrderedDict()
for key, value in lookup.iteritems():
    d_values[value] = d_normalized[key]

# %%
plt.bar(x, d_values.values(), color=lookup.keys())
plt.xticks(x+0.5, d_values.keys(), rotation=90)
plt.xlabel('Estimated productivity for horizontal well in block - 30 yr projection (Bcf)')
plt.ylabel('Frequency', rotation=0, labelpad=30)
plt.xkcd()

ax = plt.gca()
[ax.spines[s].set_visible(False) for s in ['top', 'right']]
ax.yaxis.tick_left()
ax.xaxis.set_ticks_position('none')

# %%
# Double check from the raw data:
for key, value in lookup_denormalized.iteritems():
    print "Total for " + value + " is: " + str(color_list.count(key))
# Out:
# Total for error is: 2
# Total for <0.5 is: 30
# Total for 0.5 is: 25
# Total for 0.9 is: 49
# Total for 1.2 is: 53
# Total for 1.5 is: 68
# Total for 1.9 is: 93
# Total for 2.3 is: 114
# Total for 2.8 is: 128
# Total for 3.4 is: 95
# Total for >4,3 is: 207

# %%
print d_values
# Out:
# OrderedDict([('error', 2), ('<0.5', 30), ('0.5', 25), ('0.9', 49), ('1.2', 53), ('1.5', 68), ('1.9', 93), ('2.3', 114), ('2.8', 128), ('3.4', 95), ('>4,3', 207)])
